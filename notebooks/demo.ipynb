# %% [markdown]
# # Demo Notebook
#
# Test modules interactively.

# %%
import sys
sys.path.append('../src')

from simulation import Simulation
sim = Simulation(400, 300, 10)
print(sim.grid.shape)
print('Agent:', sim.agent_pos, 'Goal:', sim.goal_pos)

# %%
from perception import Perception
p = Perception()
feed = sim.get_camera_feed()
obs = p.detect_obstacles(feed)
print('Obstacles:', obs)
